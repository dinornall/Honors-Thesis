# %% [markdown]
# # Simple Rotation

# %%
import sympy as sp
import sympy.physics.mechanics as mech
from sympy.physics.mechanics import *
import matplotlib.pyplot as plt

init_vprinting()

# %%
# Define symbols
theta = dynamicsymbols('theta')
t = sp.symbols('t')

# Define parameters
m, l, g = sp.symbols('m l g')

# %%
# Define Reference Frames
N = ReferenceFrame('N')  # Inertial frame
# dcmA rotates from N to A about N.z by angle theta
# Rotating frame A
# A = ReferenceFrame('A')  # Rotating frame
# dcmA = sp.Matrix([[sp.cos(theta), -sp.sin(theta), 0],
#                      [sp.sin(theta),  sp.cos(theta), 0],
#                      [0,              0,             1]])
# A.orient_explicit(N, dcmA)  # Rotate A about N.z by theta
#   --- OR ---
A = N.orientnew('A', 'Axis', [theta, N.z])  # Rotate A about N.z by theta

# %%
# Create points of interest

O = Point('O')  # Origin point
O.set_vel(N, 0)  # Origin point

P = O.locatenew('P', l * A.x + l* A.y)  # Point P at distance l along A.x from O

# %%
# Now, let's ask SymPy for the angular velocity of frame A in frame N
# This is a fundamental quantity: ω_A_in_N or ^Nω^A
omega_A_in_N = A.ang_vel_in(N)

omega_A_in_N

print("Velocity (v_P_in_N):")
display(P.vel(N))

print("\nAcceleration (a_P_in_N):")
display(P.acc(N))
# Out:
# Velocity (v_P_in_N):
# -l⋅θ̇ a_x + l⋅θ̇ a_y
# Acceleration (a_P_in_N):
# ⎛     2      ⎞       ⎛     2      ⎞
# ⎝- l⋅θ̇  - l⋅θ̈⎠ a_x + ⎝- l⋅θ̇  + l⋅θ̈⎠ a_y

# %% [markdown]
# # 2 DOF Arm

# %% [markdown]
# Using Lagrangian Mechanics and Sympy to find the EOMS for a double pendulum
#
# x is left and right
#
# y is in and out
#
# z is up and down

# %% [markdown]
# ## Find EOMS

# %%
import sympy as sp
from sympy import *
from sympy.physics.mechanics import *
import matplotlib.pyplot as plt

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

init_printing(use_latex=True)

# %%
# Define generalized coordinates and their derivatives
theta1, theta2 = dynamicsymbols('theta1 theta2')
dtheta1, dtheta2 = dynamicsymbols('theta1 theta2', 1)

# Define symbols (Both arms are the same)
m, L, g= sp.symbols('m L g')
t = sp.symbols('t')

# Inertia symbols
Jxx, Jyy, Jzz = sp.symbols('Jxx Jyy Jzz')

# %%
# Define Reference Frames
N = ReferenceFrame('N')  # Inertial frame
A = N.orientnew('A', 'Axis', [theta1, N.y])  # Rotating frame 1
B = A.orientnew('B', 'Axis', [theta2, A.y])  # Rotating frame 2
# Try point mass

# Set angular velocities
A.set_ang_vel(N, dtheta1 * N.y)
B.set_ang_vel(A, dtheta2 * A.y)

# Create points of interest
O = Point('O')  # Origin point
P1 = O.locatenew('P1', L * A.x)  # End point first arm
G1 = O.locatenew('G1', (L/2) * A.x)  # COM first arm
P2 = P1.locatenew('P2', L * B.x)  # End point second arm
G2 = P1.locatenew('G2', (L/2) * B.x)  # COM second arm


O.set_vel(N, 0)  # Origin point
P1.v2pt_theory(O, N, A)  # Velocity of P in N using v2pt_theory
G1.v2pt_theory(O, N, A)  # Velocity of G1 in N using v2pt_theory
P2.v2pt_theory(P1, N, B)  # Velocity of P2 in N using v2pt_theory
G2.v2pt_theory(P1, N, B)  # Velocity of G2 in N v2pt_theory
# Out:
#    d
# -L⋅──(θ₁(t)) a_z
#    dt
#    d
# -L⋅──(θ₁(t))
#    dt
# ───────────── a_z
#       2
#    d                  ⎛d           d        ⎞
# -L⋅──(θ₁(t)) a_z + -L⋅⎜──(θ₁(t)) + ──(θ₂(t))⎟ b_z
#    dt                 ⎝dt          dt       ⎠
#                       ⎛d           d        ⎞
#                    -L⋅⎜──(θ₁(t)) + ──(θ₂(t))⎟
#    d                  ⎝dt          dt       ⎠
# -L⋅──(θ₁(t)) a_z + ─────────────────────────── b_z
#    dt                           2

# %%
# Create Rigid Bodies
I1 = inertia(A, Jxx, Jyy, Jzz)  # Inertia tensor for first arm
I2 = inertia(B, Jxx, Jyy, Jzz)  # Inertia tensor for second arm

Arm1 = RigidBody('Body1', G1, A, m, (I1, G1))
Arm2 = RigidBody('Body2', G2, B, m, (I2, G2))

# %%
# Potential Energies
V1 = -m * g * dot(G1.pos_from(O), N.z)
V2 = -m * g * dot(G2.pos_from(O), N.z)

# Lagrangian
L = Lagrangian(N, Arm1, Arm2)
LM = LagrangesMethod(L, [theta1, theta2])
equations = LM.form_lagranges_equations()
equations.simplify()
display(sp.simplify(equations))
# Out:
# ⎡                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                           2  ↪
# ⎢       2                2                                                 L ⋅ ↪
# ⎢      d                d             2              d         d               ↪
# ⎢2⋅Jyy⋅───(θ₁(t)) + Jyy⋅───(θ₂(t)) - L ⋅m⋅sin(θ₂(t))⋅──(θ₁(t))⋅──(θ₂(t)) - ─── ↪
# ⎢        2                2                          dt        dt              ↪
# ⎢      dt               dt                                                     ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                              ↪
# ⎢                                                                      2       ↪
# ⎢                                        2                2           L ⋅m⋅sin ↪
# ⎢                                       d                d                     ↪
# ⎢                                   Jyy⋅───(θ₁(t)) + Jyy⋅───(θ₂(t)) + ──────── ↪
# ⎢                                         2                2                   ↪
# ⎣                                       dt               dt                    ↪
#
# ↪                                                                           2  ↪
# ↪                         2                                 2              d   ↪
# ↪              ⎛d        ⎞                                 L ⋅m⋅cos(θ₂(t))⋅─── ↪
# ↪ m⋅sin(θ₂(t))⋅⎜──(θ₂(t))⎟                     2                             2 ↪
# ↪              ⎝dt       ⎠     2              d                            dt  ↪
# ↪ ───────────────────────── + L ⋅m⋅cos(θ₂(t))⋅───(θ₁(t)) + ─────────────────── ↪
# ↪           2                                   2                      2       ↪
# ↪                                             dt                               ↪
# ↪                                                                              ↪
# ↪                                         2                 2                  ↪
# ↪                    2    2              d             2   d             2   d ↪
# ↪         ⎛d        ⎞    L ⋅m⋅cos(θ₂(t))⋅───(θ₁(t))   L ⋅m⋅───(θ₁(t))   L ⋅m⋅─ ↪
# ↪ (θ₂(t))⋅⎜──(θ₁(t))⎟                      2                 2                 ↪
# ↪         ⎝dt       ⎠                    dt                dt                d ↪
# ↪ ──────────────────── + ────────────────────────── + ─────────────── + ────── ↪
# ↪      2                             2                       4                 ↪
# ↪                                                                              ↪
#
# ↪                   2                 2        ⎤
# ↪              2   d             2   d         ⎥
# ↪ (θ₂(t))   3⋅L ⋅m⋅───(θ₁(t))   L ⋅m⋅───(θ₂(t))⎥
# ↪                    2                 2       ⎥
# ↪                  dt                dt        ⎥
# ↪ ─────── + ───────────────── + ───────────────⎥
# ↪                   2                  4       ⎥
# ↪                                              ⎥
# ↪                                              ⎥
# ↪ 2                                            ⎥
# ↪                                              ⎥
# ↪ ──(θ₂(t))                                    ⎥
# ↪  2                                           ⎥
# ↪ t                                            ⎥
# ↪ ─────────                                    ⎥
# ↪  4                                           ⎥
# ↪                                              ⎦

# %%
# 6. Solve for accelerations (q double dot)
# equivalent to: mass_matrix_inv * forcing_vector
sol = LM.rhs() 

mprint(sol)

# Find jacobian for mass matrix
# Out:
# Matrix([
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   theta1'],
# [                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   theta2'],
# [(-m*(-L**2*(theta1' + theta2')*sin(theta2)*theta2' - L**2*sin(theta2)*theta1'*theta2')/2 - (Jyy + m*(L**2*cos(theta2) + L**2/2)/2)*(-L**2*m*(theta1' + theta2')*sin(theta2)*theta1'/2 + L**2*m*sin(theta2)*theta1'*theta2'/2 + m*(Jyy + m*(L**2*cos(theta2) + L**2/2)/2)*(-L**2*(theta1' + theta2')*sin(theta2)*theta2' - L**2*sin(theta2)*theta1'*theta2')/(2*(2*Jyy + L**2*m/4 + m*(2*L**2*cos(theta2) + 5*L**2/2)/2)))/(Jyy + L**2*m/4 - (Jyy + m*(L**2*cos(theta2) + L**2/2)/2)**2/(2*Jyy + L**2*m/4 + m*(2*L**2*cos(theta2) + 5*L**2/2)/2)))/(2*Jyy + L**2*m/4 + m*(2*L**2*cos(theta2) + 5*L**2/2)/2)],
# [                                                                                                                                                                                             (-L**2*m*(theta1' + theta2')*sin(theta2)*theta1'/2 + L**2*m*sin(theta2)*theta1'*theta2'/2 + m*(Jyy + m*(L**2*cos(theta2) + L**2/2)/2)*(-L**2*(theta1' + theta2')*sin(theta2)*theta2' - L**2*sin(theta2)*theta1'*theta2')/(2*(2*Jyy + L**2*m/4 + m*(2*L**2*cos(theta2) + 5*L**2/2)/2)))/(Jyy + L**2*m/4 - (Jyy + m*(L**2*cos(theta2) + L**2/2)/2)**2/(2*Jyy + L**2*m/4 + m*(2*L**2*cos(theta2) + 5*L**2/2)/2))]])

# %% [markdown]
# ## Simulate Motion

# %%
params = [l, m, g, Iz]
# The state vector is [q1, q2, q1d, q2d]
state_sym = [q1, q2, q1d, q2d]

# Create a fast binary function from the symbolic solution
# modules='numpy' makes it use fast numpy math instead of sympy math
eom_func = lambdify((state_sym, params), sol, modules='numpy')
